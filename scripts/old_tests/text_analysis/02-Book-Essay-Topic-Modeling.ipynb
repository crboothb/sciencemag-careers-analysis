# %%
import os
from bs4 import BeautifulSoup, NavigableString, Tag 

from nltk.util import ngrams
from nltk import word_tokenize

import json
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib as plt
import seaborn as sns

import collections
import csv

from datetime import datetime
from pytz import timezone

print("imported")
# Out:
# imported

# %%
# IMPORTS SPECIFIC TO TOPIC MODELING

# import langid
import nltk
import re
import time
from collections import defaultdict
from configparser import ConfigParser
from gensim import corpora, models, similarities
from nltk.tokenize import RegexpTokenizer
from string import digits
import pyLDAvis.gensim
print("imported")
# Out:
# imported

# %%
# https://github.com/alexperrier/datatalks/blob/master/twitter/twitter_lda.py
# Initialize Parameters

corpus_filename = "all_text.mm"
dict_filename = "all_text.dict"
lda_filename = "all_text.lda"

num_topics = 6
passes = 100
alpha = 0.001

lda_params      = {'num_topics': num_topics, 'passes': passes, 'alpha': alpha}

# # Connect and get the documents
# db              = connect('twitter')
# documents       = get_documents('alexip')

# print("Corpus of %s documents" % len(documents))

# Load the corpus and Dictionary
corpus = corpora.MmCorpus(corpus_filename)
dictionary = corpora.Dictionary.load(dict_filename)

print("Running LDA with: %s  " % lda_params)
lda = models.LdaModel(corpus, id2word=dictionary,
                        num_topics=lda_params['num_topics'],
                        passes=lda_params['passes'],
                        alpha = lda_params['alpha'])
print()
lda.print_topics()
lda.save(lda_filename)
print("lda saved in %s " % lda_filename)
# Out:
# Running LDA with: {'num_topics': 6, 'passes': 100, 'alpha': 0.001}
#
# lda saved in all_text.lda

# %%
# http://nbviewer.jupyter.org/github/alexperrier/datatalks/blob/master/twitter/LDAvis.ipynb#topic=0&lambda=1&term=
# corpus = corpora.MmCorpus('section.mm')
# dictionary = corpora.Dictionary.load('sect.dict')

# %%
# First LDA model with 10 topics, 10 passes, alpha = 0.001
lda = models.LdaModel.load(lda_filename)
nyc_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
pyLDAvis.display(nyc_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1194418855283912407586968853"></div>
# <script type="text/javascript">
#
# ...

# %%
# https://github.com/alexperrier/datatalks/blob/master/twitter/twitter_lda.py
# Initialize Parameters

num_topics = 6
passes = 100
alpha = 0.001

files = [filename.split('.')[0] for filename in os.listdir('../data/dictionary_files/year/txts') if not filename.startswith('.')]
# print files

for filename in files:
    
    dict_path = '../data/dictionary_files/year/dicts/'
    corpus_path = '../data/dictionary_files/year/corpuses/'
    lda_path = '../data/dictionary_files/year/lda/'

    dict_filename   = dict_path + filename + '.dict'
    corpus_filename = corpus_path + filename + '.mm'
    lda_filename    = lda_path + filename + '.lda'
    
    lda_params      = {'num_topics': num_topics, 'passes': passes, 'alpha': alpha}

    # Load the corpus and Dictionary
    corpus = corpora.MmCorpus(corpus_filename)
    dictionary = corpora.Dictionary.load(dict_filename)

    print("Running LDA with: %s  " % lda_params)
    lda = models.LdaModel(corpus, id2word=dictionary,
                            num_topics=lda_params['num_topics'],
                            passes=lda_params['passes'],
                            alpha = lda_params['alpha'])
    print()
    lda.print_topics()
    lda.save(lda_filename)
    print("lda saved in %s " % lda_filename)
# Out:
# Running LDA with: {'num_topics': 6, 'passes': 100, 'alpha': 0.001}
#
# lda saved in ../data/dictionary_files/year/lda/1996.lda
# Running LDA with: {'num_topics': 6, 'passes': 100, 'alpha': 0.001}
#
# lda saved in ../data/dictionary_files/year/lda/1997.lda
# Running LDA with: {'num_topics': 6, 'passes': 100, 'alpha': 0.001}
#
# lda saved in ../data/dictionary_files/year/lda/1998.lda
# Running LDA with: {'num_topics': 6, 'passes': 100, 'alpha': 0.001}
#
# lda saved in ../data/dictionary_files/year/lda/1999.lda
# Running LDA with: {'num_topics': 6, 'passes': 100, 'alpha': 0.001}
#
# lda saved in ../data/dictionary_files/year/lda/2000.lda
# Running LDA with: {'num_topics': 6, 'passes': 100, 'alpha': 0.001}
#
# lda saved in ../data/dictionary_files/year/lda/2001.lda
# Running LDA with: {'num_topics': 6, 'passes': 100, 'alpha': 0.001}
#
# lda saved in ../data/dictionary_files/year/lda/2002.lda
# Running LDA with: {'num_topics': 6, 'passes': 100, 'alpha': 0.001}
#
# ...

# %%
# http://nbviewer.jupyter.org/github/alexperrier/datatalks/blob/master/twitter/LDAvis.ipynb#topic=0&lambda=1&term=
corpus = corpora.MmCorpus('../data/dictionary_files/year/corpuses/2000.mm')
dictionary = corpora.Dictionary.load('../data/dictionary_files/year/dicts/2000.dict')

# %%
# First LDA model with 10 topics, 10 passes, alpha = 0.001
lda = models.LdaModel.load('../data/dictionary_files/year/lda/2000.lda')
year_data =  pyLDAvis.gensim.prepare(lda, corpus, dictionary)
pyLDAvis.display(year_data)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\pyLDAvis\_prepare.py:257: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   return pd.concat([default_term_info] + list(topic_dfs))
# <link rel="stylesheet" type="text/css" href="https://cdn.rawgit.com/bmabey/pyLDAvis/files/ldavis.v1.0.0.css">
#
#
# <div id="ldavis_el1194418855495217368826869792"></div>
# <script type="text/javascript">
#
# ...
